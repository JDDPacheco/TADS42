# %%
pwd
# Out:
# 'C:\\Users\\josed\\TADS42\\TETI'

# %%
path = 'C:/Users/josed/TADS42/TETI/Arquivos para atividades/'

# %%
df_mun = pd.read_csv(path+'municipios.csv')

# %%
df_mun.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# %%
geometry = [Point(xy) for xy in zip(df_mun['longitude'], df_mun['latitude'])]

# %%
gdf = gpd.GeoDataFrame(df_mun, geometry=geometry)

# %%
gdf.plot(marker='o', color='green', markersize=5)
# Out:
# <Axes: >

# %%
df_mun2 = pd.read_csv(path+'municipios.csv')

# %%
df_mun2.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
geometry2 = [Point(xy) for xy in zip(df_mun2['longitude'], df_mun2['latitude'])]

# %%
gdf2 = gpd.GeoDataFrame(df_mun2, geometry=geometry2)

# %%
gdf2.plot(marker='s', color='darkblue', markersize=10)
# Out:
# <Axes: >
