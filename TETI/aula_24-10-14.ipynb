# %% [markdown]
# # Análise de dados

# %%
path = 'D:/Salve_Aqui_Seus_Arquivos/harley/TETI/Imagens/'
import pandas as pd
import seaborn as sns

# %%
df_mnp1 = pd.read_csv(path+'municipios.csv')
df_mnp2 = pd.read_csv(path+'municipios_2.csv', sep=';')
df_est = pd.read_csv(path+'estados.csv')

# %%
df_mnp1.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
df_mnp2.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
df_est.head()
# Out:
#    codigo_uf  uf      nome
# 0         11  RO  Rondônia
# 1         12  AC      Acre
# 2         13  AM  Amazonas
# 3         14  RR   Roraima
# 4         15  PA      Pará

# %%
df_est.info()
df_est.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   codigo_uf  27 non-null     int64
#  1   uf         27 non-null     object
#  2   nome       27 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 776.0+ bytes
#        codigo_uf
# count  27.000000
# mean   29.111111
# std    13.024631
# min    11.000000
# 25%    19.000000
# 50%    27.000000
# 75%    38.000000
# max    53.000000

# %%
df_mnp2.describe()
df_mnp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   codigo_ibge  5570 non-null   int64
#  1   nome         5570 non-null   object
#  2   latitude     5570 non-null   float64
#  3   longitude    5570 non-null   float64
#  4   capital      5570 non-null   int64
#  5   codigo_uf    5570 non-null   int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 261.2+ KB

# %%
df_mnp1.info()
df_mnp1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   codigo_ibge  5570 non-null   int64
#  1   nome         5570 non-null   object
#  2   latitude     5570 non-null   float64
#  3   longitude    5570 non-null   float64
#  4   capital      5570 non-null   int64
#  5   codigo_uf    5570 non-null   int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 261.2+ KB
#         codigo_ibge     latitude    longitude      capital    codigo_uf
# count  5.570000e+03  5570.000000  5570.000000  5570.000000  5570.000000
# mean   3.253591e+06   -16.449144   -46.231003     0.004847    32.377738
# std    9.849103e+05     8.287237     6.408539     0.069461     9.833862
# min    1.100015e+06   -33.686600   -72.899700     0.000000    11.000000
# 25%    2.512126e+06   -22.843875   -50.878525     0.000000    25.000000
# ...

# %%
df_mnp1.query("capital==1")
# Out:
#       codigo_ibge            nome   latitude  longitude  capital  codigo_uf
# 294       2800308         Aracaju -10.909100   -37.0677        1         28
# 580       1501402           Belém  -1.455400   -48.4898        1         15
# 592       3106200  Belo Horizonte -19.910200   -43.9266        1         31
# 642       1400100       Boa Vista   2.823840   -60.6753        1         14
# 755       5300108        Brasília -15.779500   -47.9297        1         53
# 972       5002704    Campo Grande -20.448600   -54.6295        1         50
# 1491      5103403          Cuiabá -15.601000   -56.0974        1         51
# 1508      4106902        Curitiba -25.419500   -49.2646        1         41
# 1812      4205407   Florianópolis -27.594500   -48.5477        1         42
# 1831      2304400       Fortaleza  -3.716640   -38.5423        1         23
# 1927      5208707         Goiânia -16.686400   -49.2643        1         52
# ...

# %%
df_mnp1.query("codigo_uf==13")
# Out:
#       codigo_ibge         nome  latitude  longitude  capital  codigo_uf
# 170       1300029     Alvarães  -3.22727   -64.8007        0         13
# 195       1300060      Amaturá  -3.37455   -68.2005        0         13
# 216       1300086        Anamã  -3.56697   -61.3963        0         13
# 252       1300102        Anori  -3.74603   -61.6575        0         13
# 286       1300144         Apuí  -7.19409   -59.8960        0         13
# ...           ...          ...       ...        ...      ...        ...
# 5188      1304203         Tefé  -3.36822   -64.7193        0         13
# 5259      1304237    Tonantins  -2.86582   -67.7919        0         13
# 5345      1304260       Uarini  -2.99609   -65.1133        0         13
# 5400      1304302      Urucará  -2.52936   -57.7538        0         13
# 5404      1304401  Urucurituba  -3.12841   -58.1496        0         13
#
# [62 rows x 6 columns]

# %%
df_mnp1.loc[0:10, ["nome", "codigo_ibge"]]
# Out:
#                    nome  codigo_ibge
# 0       Abadia de Goiás      5200050
# 1   Abadia dos Dourados      3100104
# 2             Abadiânia      5200100
# 3                Abaeté      3100203
# 4            Abaetetuba      1500107
# 5               Abaiara      2300101
# 6                Abaíra      2900108
# 7                 Abaré      2900207
# 8                Abatiá      4100103
# 9         Abdon Batista      4200051
# 10      Abel Figueiredo      1500131

# %%
df_mnp1.query("codigo_uf==53 & capital==1")
# Out:
#      codigo_ibge      nome  latitude  longitude  capital  codigo_uf
# 755      5300108  Brasília  -15.7795   -47.9297        1         53

# %%
df_mnp1.loc[4500:4568]
# Out:
#       codigo_ibge                         nome  latitude  longitude  capital  \
# 4500      3158409        Santana de Cataguases -21.28930   -42.5524        0
# 4501      2513505         Santana de Mangueira  -7.54705   -38.3236        0
# 4502      3547304          Santana de Parnaíba -23.44390   -46.9178        0
# 4503      3158508          Santana de Pirapama -18.99620   -44.0409        0
# 4504      2312007            Santana do Acaraú  -3.46144   -40.2118        0
# ...           ...                          ...       ...        ...      ...
# 4564      4317756    Santo Antônio do Planalto -28.40300   -52.6992        0
# 4565      3160454      Santo Antônio do Retiro -15.33930   -42.6171        0
# 4566      3160504  Santo Antônio do Rio Abaixo -19.23740   -43.2604        0
# 4567      4124400    Santo Antônio do Sudoeste -26.07370   -53.7251        0
# 4568      1507003        Santo Antônio do Tauá  -1.15220   -48.1314        0
#
#       codigo_uf
# 4500         31
# ...

# %%
df_mnp1.loc[[2881,2889,2897,3000]]
# Out:
#       codigo_ibge         nome  latitude  longitude  capital  codigo_uf
# 2881      1302504   Manacapuru  -3.29066   -60.6216        0         13
# 2889      4114302  Mandirituba -25.77700   -49.3282        0         41
# 2897      1302702     Manicoré  -5.80462   -61.2895        0         13
# 3000      3140605  Materlândia -18.46990   -43.0579        0         31

# %%
df_mnp1.codigo_uf.value_counts()
# Out:
# codigo_uf
# 31    853
# 35    645
# 43    497
# 29    417
# 41    399
# 42    295
# 52    246
# 22    224
# 25    223
# 21    217
# 26    185
# 23    184
# 24    167
# 15    144
# 51    141
# 17    139
# 27    102
# 33     92
# 50     79
# 32     78
# 28     75
# 13     62
# 11     52
# 12     22
# 16     16
# 14     15
# 53      1
# Name: count, dtype: int64

# %%
df_mnp1.groupby('codigo_uf').size()
# Out:
# codigo_uf
# 11     52
# 12     22
# 13     62
# 14     15
# 15    144
# 16     16
# 17    139
# 21    217
# 22    224
# 23    184
# 24    167
# 25    223
# 26    185
# 27    102
# 28     75
# 29    417
# 31    853
# 32     78
# 33     92
# 35    645
# 41    399
# 42    295
# 43    497
# 50     79
# 51    141
# 52    246
# 53      1
# dtype: int64

# %%
df_mun2 = df_mnp1.set_index("nome")

# %%
df_mun2.head()
# Out:
#                      codigo_ibge  latitude  longitude  capital  codigo_uf
# nome
# Abadia de Goiás          5200050 -16.75730   -49.4412        0         52
# Abadia dos Dourados      3100104 -18.48310   -47.3916        0         31
# Abadiânia                5200100 -16.19700   -48.7057        0         52
# Abaeté                   3100203 -19.15510   -45.4444        0         31
# Abaetetuba               1500107  -1.72183   -48.8788        0         15

# %%
df_mun2.loc["Manaus"]
# Out:
# codigo_ibge    1.302603e+06
# latitude      -3.118660e+00
# longitude     -6.002120e+01
# capital        1.000000e+00
# codigo_uf      1.300000e+01
# Name: Manaus, dtype: float64

# %%
df_mun2.loc[["Manaus","Presidente Figueiredo"]]
# Out:
#                        codigo_ibge  latitude  longitude  capital  codigo_uf
# nome
# Manaus                     1302603  -3.11866   -60.0212        1         13
# Presidente Figueiredo      1303536  -2.02981   -60.0234        0         13

# %%
df_mun2.loc[df_mun2.latitude < 0]
# Out:
#                      codigo_ibge  latitude  longitude  capital  codigo_uf
# nome
# Abadia de Goiás          5200050 -16.75730   -49.4412        0         52
# Abadia dos Dourados      3100104 -18.48310   -47.3916        0         31
# Abadiânia                5200100 -16.19700   -48.7057        0         52
# Abaeté                   3100203 -19.15510   -45.4444        0         31
# Abaetetuba               1500107  -1.72183   -48.8788        0         15
# ...                          ...       ...        ...      ...        ...
# Xique-Xique              2933604 -10.82300   -42.7245        0         29
# Zabelê                   2517407  -8.07901   -37.1057        0         25
# Zacarias                 3557154 -21.05060   -50.0552        0         35
# Zé Doca                  2114007  -3.27014   -45.6553        0         21
# Zortéa                   4219853 -27.45210   -51.5520        0         42
#
# [5543 rows x 5 columns]

# %% [markdown]
# ### iloc

# %%
df_mnp1.iloc[-1]
# Out:
# codigo_ibge    4219853
# nome            Zortéa
# latitude      -27.4521
# longitude      -51.552
# capital              0
# codigo_uf           42
# Name: 5569, dtype: object

# %%
df_mnp1.iloc[0:10, 0:2]
# Out:
#    codigo_ibge                 nome
# 0      5200050      Abadia de Goiás
# 1      3100104  Abadia dos Dourados
# 2      5200100            Abadiânia
# 3      3100203               Abaeté
# 4      1500107           Abaetetuba
# 5      2300101              Abaiara
# 6      2900108               Abaíra
# 7      2900207                Abaré
# 8      4100103               Abatiá
# 9      4200051        Abdon Batista

# %%
df_mnp1['latitude'].hist()
# Out:
# <Axes: >

# %%
df_mnp1['longitude'].hist()
# Out:
# <Axes: >

# %%
df_mnp1.merge(df_est, how="inner", on="codigo_uf")
# Out:
#       codigo_ibge               nome_x  latitude  longitude  capital  \
# 0         5200050      Abadia de Goiás -16.75730   -49.4412        0
# 1         3100104  Abadia dos Dourados -18.48310   -47.3916        0
# 2         5200100            Abadiânia -16.19700   -48.7057        0
# 3         3100203               Abaeté -19.15510   -45.4444        0
# 4         1500107           Abaetetuba  -1.72183   -48.8788        0
# ...           ...                  ...       ...        ...      ...
# 5565      2933604          Xique-Xique -10.82300   -42.7245        0
# 5566      2517407               Zabelê  -8.07901   -37.1057        0
# 5567      3557154             Zacarias -21.05060   -50.0552        0
# 5568      2114007              Zé Doca  -3.27014   -45.6553        0
# 5569      4219853               Zortéa -27.45210   -51.5520        0
#
#       codigo_uf  uf          nome_y
# 0            52  GO           Goiás
# 1            31  MG    Minas Gerais
# ...

# %%
df_est_mun = df_mnp1.merge(df_est, how="inner", on="codigo_uf")

# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.1/3.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 7.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_tabam = pd.read_html('https://en.wikipedia.org/wiki/Amazonas_(Brazilian_state)')

# %%
df_tabam = pd.read_html('https://en.wikipedia.org/wiki/Amazonas_(Brazilian_state)', match = 'Historical population')

# %%
df_tabam[0]
# Out:
#           Year        Pop.          ±%
# 0         1872       57610           —
# 1         1890      147915     +156.8%
# 2         1900      249756      +68.9%
# 3         1920      363166      +45.4%
# 4         1940      438008      +20.6%
# 5         1950      514099      +17.4%
# 6         1960      721215      +40.3%
# 7         1970      960934      +33.2%
# 8         1980     1449135      +50.8%
# 9         1991     2102901      +45.1%
# 10        2000     2817252      +34.0%
# 11        2010     3483985      +23.7%
# 12        2022     3941613      +13.1%
# 13  Source:[1]  Source:[1]  Source:[1]

# %%
df_pop_am = df_tabam[0]

# %%
df_pop_am = df_pop_am[:13]

# %%
df_pop_am
# Out:
#     Year     Pop.       ±%
# 0   1872    57610        —
# 1   1890   147915  +156.8%
# 2   1900   249756   +68.9%
# 3   1920   363166   +45.4%
# 4   1940   438008   +20.6%
# 5   1950   514099   +17.4%
# 6   1960   721215   +40.3%
# 7   1970   960934   +33.2%
# 8   1980  1449135   +50.8%
# 9   1991  2102901   +45.1%
# 10  2000  2817252   +34.0%
# 11  2010  3483985   +23.7%
# 12  2022  3941613   +13.1%

# %%
df_pop_am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    13 non-null     object
#  1   Pop.    13 non-null     object
#  2   ±%      13 non-null     object
# dtypes: object(3)
# memory usage: 440.0+ bytes

# %%
df_pop_am = df_pop_am['Year'].astype('int')

# %%
df_pop_am = df_pop_am['Year'].astype('int')

# %% [markdown]
# # Processamento de imagem

# %%
path_img = 'D:/Salve_Aqui_Seus_Arquivos/DIOGO/TADS42/TETI/Arquivos para atividades/teti_imagens/'

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
# %matplotlib inline

# %%
from pylab import *

# %%
im1 = array(Image.open(path_img + 'trees.jpg'))marina-bay-sands

# %%
imshow(im1)

# %%
im1.shape
# Out:
# (1017, 1882, 3)

# %%
def plot_2img (im1, tit1, im2, tit2, tam):
    figure(figsize = tam)
    plt.subplot(1, 2, 1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 2, 2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
def plot_3img (im1, tit1, im2, tit2, im3, tit3, tam):
    figure(figsize = tam)
    plt.subplot(1, 3, 1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 3, 2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 3, 3), plt.imshow(im3), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
def plot_2img_gray (im1, tit1, im2, tit2, tam):
    figure(figsize = tam)
    plt.subplot(1, 2, 1), plt.imshow(im1, cmap = 'gray'), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 2, 2), plt.imshow(im2, cmap = 'gray'), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
plot_2img(im1, 'Imagem', im1, 'Imagem', (12,10))

# %%
plot_3img(im1, 'Imagem', im1, 'Imagem', im1, 'Imagem', (12,10))

# %%
im1_ = im1.ravel()

# %%
im1_
# Out:
# array([125, 193, 232, ...,  87,  70,  52], dtype=uint8)

# %%
np.save('saida_img', im1)

# %%
pwd
# Out:
# 'D:\\Salve_Aqui_Seus_Arquivos\\DIOGO\\TADS42\\TETI'

# %%
plt.hist(im1_)
# Out:
# (array([ 466549.,  424025.,  363002.,  285137.,  383366.,  403156.,
#          395905.,  850799., 1574523.,  595520.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
im1_r = im1[:,:,0]
im1_g = im1[:,:,1]
im1_b = im1[:,:,2]

# %%
plot_2img(im1, 'Original', im1_g, 'G', (12,10))

# %%
plot_2img(im1, 'Original', im1_r, 'R', (12,10))

# %%
plot_2img(im1, 'Original', im1_b, 'B', (12,10))

# %%
plot_2img_gray(im1, 'Original', im1_g, 'G', (12,10))

# %%
plot_2img_gray(im1, 'Original', im1_r, 'R', (12,10))

# %%
plot_2img_gray(im1, 'Original', im1_b, 'B', (12,10))

# %%
im1_ = im1[720:800, 780:1000]

# %%
imshow(im1_)

# %%
im2 = array(Image.open(path_img + 'marina-bay-sands.jpg'))

# %%
im1_ = im2[2342:2380, 334:350]
imshow(im1_)
